# %% [markdown]
# # Carbon Bombs Flowchart– Workflow Overview
#
# This is a flowchart describing the main inputs,
# processes, and outputs of the Carbon Bombs analysis code.

# %% [markdown]
# ![Carbon Bombs workflow flowchart](flowchart_carbon_bombs.png)

# %% [markdown]
# flowchart TD
#   A([Start]) --> B["Import libraries"]
#
#   B --> C["Load Carbon Bombs dataset"]
#   C --> D["Pre-process data"]
#   D --> E["Create xarray dataset"]
#   E --> F["Load exposure datasets"]
#   F --> G["Prepare geographic boundaries"]
#   G --> H["Aggregate results"]
#   H --> I["Join results with geography"]
#
#   I --> J["Emissions analysis outputs\nBar charts\nCountry totals"]
#   I --> K["Exposure analysis outputs\nMaps\nRegional summaries"]
#
#   J --> L([End])
#   K --> L([End])
